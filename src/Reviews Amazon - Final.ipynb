# %%
import pandas as pd
from tqdm._tqdm_notebook import tqdm_notebook
from gensim.models import KeyedVectors
import warnings
from spacy import displacy 
import numpy as np
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
import spacy
import re
import string
from nltk.corpus import stopwords
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from nltk.cluster import KMeansClusterer, euclidean_distance
import nltk
from yellowbrick.text import TSNEVisualizer
import matplotlib.pyplot as plt
from IPython.core.display import HTML
from wordcloud import WordCloud

warnings.filterwarnings('ignore')
tqdm_notebook.pandas()

# %%
df = pd.read_csv("../data/amazon_reviews.csv", sep=";")

# %%
df.shape
# Out:
# (35, 2)

# %%
df.head()
# Out:
#                                               review produto
# 0  Não posso comparar com as outras geração pois ...  kindle
# 1  Aparelho excelente, porém o site está com falt...  kindle
# 2  Que bom que colocaram iluminação nesse novo Ki...  kindle
# 3  Maravilhoso, anatômico e a luz realmente faz d...  kindle
# 4  Amei esse kindle! Já tinha o outro, mais básic...  kindle

# %%
df["produto"].value_counts()
# Out:
# kindle              11
# echodot             10
# livro                9
# petisco_cachorro     5
# Name: produto, dtype: int64

# %%
df["tamanho_review"] = df["review"].apply(lambda x : len(x.split()))

# %%
df["tamanho_review"].describe()
# Out:
# count     35.000000
# mean      46.542857
# std       32.842174
# min        9.000000
# 25%       21.000000
# 50%       37.000000
# 75%       57.500000
# max      122.000000
# Name: tamanho_review, dtype: float64

# %% [markdown]
# # Pos-tagging
#
# Quero capturar itens específicos no meu texto, por isso vou aplicar o pos-tagging.
#
# - Pos-tagging é a anotação de cada palavra em uma sentença, com um part-of-speech (marcador)
# - Nível mais baixo da análise sintática: substantivo, verbo, pronome, preposição, adverbio, conjunção, artigos
#
#
# https://spacy.io/api/annotation

# %%
nlp = spacy.load("pt_core_news_sm")

# %%
texto = df.loc[32, "review"]
texto
# Out:
# 'Minhas cachorras amaram, entregou super rápido, só que vieram muitos quebrados.'

# %%
doc = nlp(texto)

# %%
displacy.render(doc, style='dep',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="f72eb387aefc4f85a669a516c9012d7a-0" class="displacy" width="1975" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Minhas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">cachorras</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">amaram,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">entregou</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">super</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">rápido,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">só</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">que</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">vieram</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">muitos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">quebrados.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f72eb387aefc4f85a669a516c9012d7a-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f72eb387aefc4f85a669a516c9012d7a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f72eb387aefc4f85a669a516c9012d7a-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f72eb387aefc4f85a669a516c9012d7a-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f72eb387aefc4f85a669a516c9012d7a-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f72eb387aefc4f85a669a516c9012d7a-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M565.0,266.5 L573.0,254.5 557.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f72eb387aefc4f85a669a516c9012d7a-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f72eb387aefc4f85a669a516c9012d7a-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,266.5 L748.0,254.5 732.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f72eb387aefc4f85a669a516c9012d7a-0-4" stroke-width="2px" d="M595,264.5 C595,89.5 920.0,89.5 920.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f72eb387aefc4f85a669a516c9012d7a-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,266.5 L928.0,254.5 912.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f72eb387aefc4f85a669a516c9012d7a-0-5" stroke-width="2px" d="M1120,264.5 C1120,89.5 1445.0,89.5 1445.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f72eb387aefc4f85a669a516c9012d7a-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,266.5 L1112,254.5 1128,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f72eb387aefc4f85a669a516c9012d7a-0-6" stroke-width="2px" d="M1120,264.5 C1120,177.0 1265.0,177.0 1265.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f72eb387aefc4f85a669a516c9012d7a-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">fixed</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1265.0,266.5 L1273.0,254.5 1257.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f72eb387aefc4f85a669a516c9012d7a-0-7" stroke-width="2px" d="M420,264.5 C420,2.0 1450.0,2.0 1450.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f72eb387aefc4f85a669a516c9012d7a-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1450.0,266.5 L1458.0,254.5 1442.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f72eb387aefc4f85a669a516c9012d7a-0-8" stroke-width="2px" d="M1645,264.5 C1645,177.0 1790.0,177.0 1790.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em;

# %%
df['substantivos'] = ""
df['substantivos'] = df['substantivos'].astype(object)

# %%
for i in df.index:
    pos_tags = {}
    doc = nlp(df.loc[i, "review"])
    for d in doc:
        if d.pos_ not in pos_tags.keys():
            #pos_tags[d.pos_] = [str(d.lemma_).lower()]
            pos_tags[d.pos_] = [str(d.text).lower()]
        else:
            pos_tags[d.pos_].append(str(d.text).lower())
    df.at[i, "substantivos"] = list(set(pos_tags["NOUN"]))

# %%
df.head()
# Out:
#                                               review produto  tamanho_review  \
# 0  Não posso comparar com as outras geração pois ...  kindle              57
# 1  Aparelho excelente, porém o site está com falt...  kindle              43
# 2  Que bom que colocaram iluminação nesse novo Ki...  kindle              44
# 3  Maravilhoso, anatômico e a luz realmente faz d...  kindle              15
# 4  Amei esse kindle! Já tinha o outro, mais básic...  kindle              25
#
#                                         substantivos
# 0  [geração, dias, diferença, celular, pessoa, me...
# 1  [detalhes, dias, capas, perfeccionistas, site,...
# 2  [suficiente, geração, lugar, dia, paperwhite, ...
# 3                  [luz, vistas, leitura, diferença]
# 4  [diferença, luz, causa, ambientes, iluminação,...

# %%
df["qtde_subs"] = df["substantivos"].apply(lambda x:len(x))

# %%
df["qtde_subs"].describe()
# Out:
# count    35.000000
# mean      8.628571
# std       5.951202
# min       1.000000
# 25%       5.000000
# 50%       7.000000
# 75%      10.500000
# max      23.000000
# Name: qtde_subs, dtype: float64

# %% [markdown]
# # Uma forma de representar os substantivos
#
# Precisamos de uma forma de representar os substantivos para que máquina entenda as relações entre eles. Para isso vamos utilizar embeddings (Word2Vec).
#
# - Word2Vec é uma forma de representar o texto onde o contexto (palavras ao redor) é considerado.
# - Vetores similares representam palavras similares, com semântica ou função semelhante.
#
# Aqui vamos utilizar um embedding de 300 dimensões treinado com todos os dados da Wikipedia.
#
#
# <i> Download embedding: https://wikipedia2vec.github.io/wikipedia2vec/pretrained/</i>

# %%
# %%time
word_vectors = KeyedVectors.load_word2vec_format("../data/ptwiki_20180420_300d.txt.bz2", binary=False,unicode_errors='ignore' )
# Out:
# CPU times: user 7min 2s, sys: 1.92 s, total: 7min 4s
# Wall time: 7min 4s

# %% [markdown]
# ## Conhecendo word2vec

# %% [markdown]
# ### Vetor

# %%
word_vectors["cão"].shape
# Out:
# (300,)

# %%
word_vectors["cão"]
# Out:
# array([-0.1632, -0.1828, -0.0052,  0.0658, -0.1079, -0.1572, -0.0794,
#         0.2208,  0.1396, -0.4451,  0.0578, -0.2792,  0.2066, -0.0735,
#         0.0328,  0.056 ,  0.2421, -0.1304, -0.0072, -0.1039,  0.3202,
#         0.3375, -0.1736,  0.6777,  0.3871,  0.1219, -0.2116, -0.0244,
#        -0.4804, -0.4236,  0.0892, -0.2086,  0.2255,  0.1165, -0.1407,
#         0.3517, -0.0386, -0.106 , -0.1073, -0.2136, -0.0548, -0.2278,
#        -0.0846,  0.3565,  0.5464, -0.2482,  0.055 , -0.1286,  0.0649,
#        -0.215 , -0.4479,  0.0795, -0.3385, -0.0975,  0.1162,  0.0215,
#        -0.0024,  0.321 ,  0.1029, -0.3608,  0.1746,  0.351 , -0.2545,
#        -0.3504, -0.2809, -0.2256,  0.2534, -0.2477, -0.2499,  0.1877,
#        -0.0017,  0.1246,  0.1975, -0.2199, -0.3326,  0.3624,  0.0203,
#        -0.3047,  0.0273,  0.282 ,  0.0877,  0.6082, -0.0883,  0.0558,
#        -0.1136,  0.2575, -0.3499, -0.0706, -0.0227,  0.1579, -0.1956,
#        -0.5313,  0.2964, -0.3597,  0.1097, -0.2281,  0.127 , -0.3788,
#         0.446 , -0.6404,  0.0878,  0.2106, -0.1864, -0.5121,  0.0996,
#        -0.0102, -0.5245, -0.2969,  0.1019, -0.1109, -0.159 , -0.1231,
#        -0.0214, -0.2326, -0.4713,  0.5923,  0.3727, -0.0167, -0.196 ,
#        -0.1526,  0.0751,  0.3927, -0.4611, -0.1911, -0.6126, -0.3448,
#         0.1252, -0.2151, -0.3061,  0.2882,  0.0635, -0.0873, -0.0638,
#        -0.0306, -0.0168,  0.2713, -0.1693,  0.1711,  0.3062,  0.1049,
#        -0.4192,  0.3439,  0.1052, -0.303 ,  0.1982, -0.1653, -0.2225,
#         0.229 ,  0.0534, -0.3102, -0.226 , -0.1642,  0.0679,  0.2281,
#        -0.2842, -0.5816, -0.4484,  0.0692, -0.3277, -0.646 ,  0.3061,
#        -0.031 , -0.1528,  0.1015, -0.2861,  0.3463, -0.397 ,  0.5192,
#         0.038 ,  0.619 , -0.2028,  0.089 , -0.1312, -0.4416,  0.1941,
#        -0.321 , -0.0345,  0.3615, -0.0526, -0.082 , -0.1114,  0.1329,
#         0.2112, -0.3172, -0.0784,  0.1851, -0.2646, -0.3526, -0.1465,
#         0.2167, -0.0075, -0.0029, -0.1392, -0.1254,  0.0756,  0.0102,
#         0.1567,  0.2725,  0.0227,  0.1354,  0.0232, -0.1131, -0.0967,
#        -0.1277, -0.3228, -0.1596, -0.4865, -0.023 , -0.0063, -0.1242,
#        -0.1604, -0.0022,  0.166 ,  0.057 ,  0.0116,  0.0722, -0.5509,
#        -0.0543,  0.0632, -0.1868,  0.0951, -0.1435,  0.1253, -0.5429,
#         0.2457, -0.2335,  0.2374,  0.1227,  0.1688,  0.0874, -0.0646,
#         0.0234, -0.3077,  0.2703, -0.0068,  0.072 , -0.114 , -0.3437,
#        -0.0514, -0.0233,  0.6893,  0.1895,  0.1231, -0.7092, -0.4651,
#         0.1746,  0.302 , -0.0166, -0.1347,  0.0335,  0.0133, -0.2014,
#        -0.327 ,  0.0806, -0.0717,  0.36  , -0.2089,  0.0852, -0.2839,
#        -0.0909,  0.3238, -0.1395,  0.4697,  0.0744, -0.2997,  0.2307,
#         0.1508,  0.1975, -0.0988, -0.2304,  0.0876,  0.0115, -0.2215,
#        -0.0981, -0.0723,  0.0222, -0.2674, -0.1786,  0.0714, -0.0129,
#        -0.2549, -0.3042,  0.315 , -0.2649, -0.2075, -0.5053,  0.2417,
#        -0.2415, -0.2432, -0.3075, -0.0206, -0.2604, -0.0579,  0.154 ,
#        -0.3229, -0.1941,  0.1835,  0.0228, -0.1494, -0.3043],
#       dtype=float32)

# %% [markdown]
# ### Similaridades

# %%
word_vectors.most_similar("cão")
# Out:
# [('cães', 0.7167638540267944),
#  ('cachorro', 0.6982829570770264),
#  ('uivador', 0.6609100103378296),
#  ('mastim', 0.6308091878890991),
#  ('utonagan', 0.6215323209762573),
#  ('farejador', 0.6205751299858093),
#  ('lebréu', 0.6139198541641235),
#  ('dogue', 0.6133594512939453),
#  ('bullmastiff', 0.6107551455497742),
#  ('saarloos', 0.6063539981842041)]

# %%
word_vectors.most_similar("raiva")
# Out:
# [('tristeza', 0.6553449630737305),
#  ('medo', 0.6445415019989014),
#  ('ódio', 0.6321556568145752),
#  ('ciúmes', 0.629055917263031),
#  ('misofobia', 0.6081965565681458),
#  ('ciúme', 0.6058832406997681),
#  ('inveja', 0.6041990518569946),
#  ('autopunição', 0.6039630174636841),
#  ('estupefacção', 0.5981924533843994),
#  ('frustração', 0.5971919298171997)]

# %%
word_vectors.wv.most_similar(positive=['mulher', 'rei'], negative=['homem'], topn=10)
# Out:
# [('rainha', 0.6761009097099304),
#  ('consorte', 0.5897642374038696),
#  ('princesa', 0.5725809931755066),
#  ('esposa', 0.5474461913108826),
#  ('infanta', 0.5159229040145874),
#  ('monarca', 0.5138536095619202),
#  ('masenate', 0.5088573694229126),
#  ('savang', 0.5054910778999329),
#  ('ulvhild', 0.5024229288101196),
#  ('filha', 0.5023597478866577)]

# %%
word_vectors.wv.most_similar(positive=['pai', 'mãe'], negative=['avô'], topn=10)
# Out:
# [('avó', 0.6942551136016846),
#  ('esposa', 0.6712349057197571),
#  ('irmã', 0.6597204208374023),
#  ('filha', 0.642005443572998),
#  ('marido', 0.6241066455841064),
#  ('madrasta', 0.6163579225540161),
#  ('esposo', 0.6144749522209167),
#  ('adotiva', 0.6069194674491882),
#  ('tia', 0.6024690866470337),
#  ('sogra', 0.5972339510917664)]

# %% [markdown]
# ## Aplicando o word2vec
#
# Temos vários substantivos representando as reviews. Agora queremos capturar os vetores de cada um dos substantivos e precisamos gerar um vetor que representa toda a review. Para isto, vamos tirar a média dos vetores dos substantivos das frases.

# %%
def calcula_embedding_frase(tokens):
    return np.mean(np.array([word_vectors[t] for t in tokens if t in word_vectors.vocab]), axis=0)

# %%
embedding_reviews = [calcula_embedding_frase(e) for e in df["substantivos"].values]

# %%
X = np.array(embedding_reviews)

# %% [markdown]
# # Encontrar grupos
#
# Já temos os substantivos das reviews representados por vetores. Agora precisamos descobrir em quantos grupos conseguimos separar as nossas reviews.
# Para isso, iremos aplicar o método elbow.

# %%
SS = StandardScaler()
X = SS.fit_transform(X)

# %%
model = KMeans(random_state=123)
visualizer = KElbowVisualizer(model, k=(2,12))
visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %% [markdown]
# ## Realização da  clusterização

# %%
qtde_cluster = 5

# %%
clusterer = KMeansClusterer(qtde_cluster, euclidean_distance, repeats=100)
clusters = clusterer.cluster(X, True)

# %%
df["cluster"] = clusters

# %% [markdown]
# ## Quais são esses grupos?

# %%
fig, ax = plt.subplots() 
tsne = TSNEVisualizer(random_state=12,perplexity=12,learning_rate=3, n_iter=2000)#, metric="cosine")
tsne.fit(X, clusters)
tsne.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
for c in sorted(df["cluster"].unique()):
    print("Cluster ", c)
    display(HTML(df[df["cluster"] == c].to_html()))
# Out:
# Cluster  0
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>review</th>
#       <th>produto</th>
#       <th>tamanho_review</th>
#       <th>substantivos</th>
#       <th>qtde_subs</th>
#       <th>cluster</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30</th>
#       <td>Sério, os cachorros ficam meio enlouquecidos querendo mais, adoraram.</td>
#       <td>petisco_cachorro</td>
#       <td>9</td>
#       <td>[cachorros]</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>Meu cachorro adorou, estou usando como recompensa pra aprender a usar um tapete higiênico e tem dado certo por enquanto! Recomendo bastante tanto para raças pequenas como grandes</td>
#       <td>petisco_cachorro</td>
#       <td>28</td>
#       <td>[raças, enquanto, recompensa, tapete, cachorro]</td>
#       <td>5</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>Minhas cachorras amaram, entregou super rápido, só que vieram muitos quebrados.</td>
#       <td>petisco_cachorro</td>
#       <td>11</td>
#       <td>[super, quebrados, cachorras]</td>
#       <td>3</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>Pratico e durável, minha cadela ama! Perfeito para levar como petisco durante uma caminhada ou passeio!</td>
#       <td>petisco_cachorro</td>
#       <td>16</td>
#       <td>[caminhada, cadela, passeio, petisco, pratico]</td>
#       <td>5</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>Excelente biscoito, meu cachorro adorou. E pelo preço que paguei, saiu bem em conta. Recomendo</td>
#       <td>petisco_cachorro</td>
#       <td>15</td>
#       <td>[preço, cachorro, biscoito, conta]</td>
#       <td>4</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# Cluster  1
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>review</th>
#       <th>produto</th>
#       <th>tamanho_review</th>
#       <th>substantivos</th>
#       <th>qtde_subs</th>
#       <th>cluster</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Não posso comparar com as outras geração pois esse é meu primeiro Kindle, mas como uma pessoa que gosta muito de ler e lia muito pelo celular, o Kindle tem uma enorme diferença, meu maior medo era que os olhos doessem, o que não aconteceu. Ele é maravilhoso. Só não recebi os 90 dias de kindle unlimited!</td>
#       <td>kindle</td>
#       <td>57</td>
#       <td>[geração, dias, diferença, celular, pessoa, medo, olhos]</td>
#       <td>7</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Que bom que colocaram iluminação nesse novo Kindle de 10ª geração pois prefiro o design dele ao paperwhite! Agora ficou perfeito, ótimo custo benefício, é o suficiente pra quem gosta de ler a qualquer hora do dia ou da noite e em qualquer lugar!</td>
#       <td>kindle</td>
#       <td>44</td>
#       <td>[suficiente, geração, lugar, dia, paperwhite, hora, iluminação, noite, design]</td>
#       <td>9</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Maravilhoso, anatômico e a luz realmente faz diferença na leitura. Não pesa as vistas. Perfeito</td>
#       <td>kindle</td>
#       <td>15</td>
#       <td>[luz, vistas, leitura, diferença]</td>
#       <td>4</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Amei esse kindle! Já tinha o outro, mais básico, mas a iluminação faz toda a diferença por causa da variação de luz dos ambientes externos.</td>
#       <td>kindle</td>
#       <td>25</td>
#       <td>[diferença, luz, causa, ambientes, iluminação, variação]</td>
#       <td>6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Desde a época que comprei meu primeiro Kindle, há aproximadamente 4 anos eu fiquei impressionado com a qualidade dos produtos Amazon e o Echo Dot faz jus ao nome. A qualidade da caixa sonora é impecável, não cheguei a usar no máximo com certo receio de perturbar os vizinhos (moro em apartamento), a Alexa responde de forma rápida aos comandos, apesar de ainda cometer alguns erros. Com a prática tem-se a perfeição. O usuário também precisa aprender a como se comunicar com a Alexa e sempre reportar os possíveis erros de comunicação pro aperfeiçoamento do sistema. Creio que a Alexa veio pra ficar e com esse dispositivo de alta qualidade como o Echo Dot, é possível utilizar a assistente ao máximo. Recomendo.</td>
#       <td>kindle</td>
#       <td>122</td>
#       <td>[máximo, comunicação, receio, aperfeiçoamento, assistente, comandos, jus, anos, produtos, perfeição, erros, sistema, época, caixa, moro, apartamento, nome, usuário, forma, dispositivo, vizinhos, prática, qualidade]</td>
#       <td>23</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Aparelho veio com defeito, frustrante. Muita demora para resolver. Penso em devolver se não trocarem</td>
#       <td>echodot</td>
#       <td>15</td>
#       <td>[demora, aparelho, defeito]</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Muito boa. Ela tem design e dimensões bem discretas, serve para colocar em qualquer cômodo da cada sem medo de estragar a decoração ou algo do tipo (muito pelo contrário, ela combina com tudo!). A qualidade de som, comparado ao porte dela, é muito boa. Só calibrei um pouco os graves, para não ficar tão agudo e lá estava o som com uma qualidade bem legal. Volume suficiente para curtir um som sem incomodar vizinhos e afins, desde que seja ambiente interno (é claramente o foco dessa caixa, dado o porte). Os microfones tem um ótimo alcance e a Alexa funciona muito bem. Recomendo!</td>
#       <td>echodot</td>
#       <td>104</td>
#       <td>[decoração, contrário, alcance, ambiente, cômodo, foco, graves, medo, tipo, porte, dimensões, volume, caixa, afins, vizinhos, qualidade, som, microfones, design]</td>
#       <td>19</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Comprei uma lâmpada Yeeligth que é compatível com a Alexa, porem não tem SKILL liberada para português e não consigo instalar skill de outra lingua. Não me importo em falar em inglês para acender a lampada, mais fico puto de comprar uma lampada e não poder usar por causa da Alexa. Decepcionado....</td>
#       <td>echodot</td>
#       <td>52</td>
#       <td>[lingua, yeeligth, lâmpada, skill, lampada, português, causa, inglês]</td>
#       <td>8</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# Cluster  2
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>review</th>
#       <th>produto</th>
#       <th>tamanho_review</th>
#       <th>substantivos</th>
#       <th>qtde_subs</th>
#       <th>cluster</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5</th>
#       <td>É um produto que vale cada centavo! Estimula demais a leitura, é prático e super leve pra levar pra qualquer lugar.</td>
#       <td>kindle</td>
#       <td>21</td>
#       <td>[centavo, leitura, produto, lugar]</td>
#       <td>4</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Comprei o Kindle 10a geração acreditando que ele ia vir com os 4 GB, como a própria Amazon especifica na propaganda do produto e acreditando no que vem escrito na caixa do aparelho. E podem ter certeza de que não vêm. Me sinto extremamente enganada pela Amazon, o aparelho é lindo, comprei a cor branca por achar mais clássica e não me enganei quanto à isso, o design dele é espetacularmente lindo e bem delicado, mas quanto aos 4 GB que MENTIRA isso, paguei caro em um produto para não vir o que foi prometido. Que feio isso Amazon!!!</td>
#       <td>kindle</td>
#       <td>99</td>
#       <td>[geração, feio, produto, certeza, propaganda, caixa, cor, aparelho, paguei, 4, design]</td>
#       <td>11</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>A bateria do meu Kindle não dura nem 3 dias. Não sei o que está acontecendo, já que o prometido era semanas. E digo isso levando em consideração que eu não utilizo nem 2 horas por dia</td>
#       <td>kindle</td>
#       <td>37</td>
#       <td>[prometido, dias, dia, horas, consideração, bateria, semanas]</td>
#       <td>7</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Eu possuía o kindle 7ª geração e vendi a fim de pegar p 10º (em função da iluminação embutida). Porém, estou amargamente arrependida. A bateria do meu anterior durava até 1 mês e meio, o 10ª geração com uma leitura de duas horas por dia (wifi desligado e iluminação no 12) dura em torno de 5 dias. Pedi troca do produto, comprei outro e pasmem! Veio da mesma forma. Eu mexo 5 minutos e a bateria já desce 5%! Aparentemente é a qualidade do aparelho que é inferior. Uma pena, sempre defendi os produtos da Amazon mas esse kindle novo deixou muuuuito a desejar. O diferencial do kindle é justamente a bateria e a desse é péssima. Mega insatisfeita.</td>
#       <td>kindle</td>
#       <td>119</td>
#       <td>[geração, meio, pena, iluminação, função, dias, minutos, horas, produtos, torno, dia, dura, bateria, mês, forma, muuuuito, aparelho, fim, produto, qualidade, diferencial, leitura]</td>
#       <td>22</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Eu particularmente odiei, detestei o produto, eu ja tinha um iPad Pro e um Mini iPad, e resolvi comprar o Kindle, que erro que eu cometi!!! O processador dele é extremamente lento, existe um delay para os comandos em touch, uma porcaria! Arrependido!!!</td>
#       <td>kindle</td>
#       <td>43</td>
#       <td>[delay, processador, produto, comandos, ipad, erro, porcaria]</td>
#       <td>7</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Acho que a propaganda desse produto está sendo feita de forma errada hora nenhuma ele dá a impressão de que você precisa manter ele ligado em uma tomada para funcionar, vejam as fotos a forma de divulgação da impressão de ser algo com bateria que vc carrega pra cima e pra baixo, é bem chato isso. Apesar de não estar escrito sobre bateria no anúncio você tem essa impressão. O aparelho é bom, funciona tudo que promete mas fiquei bem chateado ao perceber que não existe o recurso de bateria e acho que deveria ficar bem explicita essa informação, decepção é o que define o que sinto.</td>
#       <td>echodot</td>
#       <td>107</td>
#       <td>[recurso, produto, impressão, decepção, propaganda, informação, divulgação, hora, bateria, cima, forma, anúncio, aparelho, chato, tomada, fotos]</td>
#       <td>16</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>Recomendo a leitura para aqueles que têm o hábito de deixar para depois aquilo que deve ser feito. Irão se sentir muito melhores e sem o sentimento de culpa usual nos procrastinadores, se conseguirem reduzir/eliminar este hábito.</td>
#       <td>livro</td>
#       <td>37</td>
#       <td>[hábito, procrastinadores, leitura, culpa, sentimento]</td>
#       <td>5</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# Cluster  3
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>review</th>
#       <th>produto</th>
#       <th>tamanho_review</th>
#       <th>substantivos</th>
#       <th>qtde_subs</th>
#       <th>cluster</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Aparelho excelente, porém o site está com falta de capas para o aparelho, acredito ser um probleminha que incomoda para os mais perfeccionistas, um site tão grande deve se atentar a esses detalhes também não ganhei os 90 dias prometidos de kindle ulimited</td>
#       <td>kindle</td>
#       <td>43</td>
#       <td>[detalhes, dias, capas, perfeccionistas, site, probleminha, falta, aparelho]</td>
#       <td>8</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Recomendo esse livro para todos aqueles que querem "virar a chave" e começar a agir. Não é aqueles livros de autoajuda chatos que ficam dando fórmulas mágicas. É um livro para auto reflexão, especialmente pelos exemplos apresentados. Apresenta fundamentos científicos que explicam com bastante propriedade acerca do assunto.</td>
#       <td>livro</td>
#       <td>48</td>
#       <td>[livros, fundamentos, fórmulas, propriedade, autoajuda, chave, livro, assunto, exemplos]</td>
#       <td>9</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Li em torno de 5 livros sobre a procrastinação e este foi o mais completo dentro desta proposta. Recomendo !</td>
#       <td>livro</td>
#       <td>20</td>
#       <td>[livros, proposta, torno, procrastinação, li]</td>
#       <td>5</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Adorei o livro, simples e direto. Foi indicação da minha Pisicologa e me ajudou muito, pois sou procrastinadora. Indico para todas as pessoas que têm dificuldades de planejar e executar.</td>
#       <td>livro</td>
#       <td>30</td>
#       <td>[pessoas, indicação, dificuldades, livro, indico]</td>
#       <td>5</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>Livro excelente, não só escreve os sintomas e ações dos procrastinadores com oferece várias técnicas e procedimentos para superar este problema.</td>
#       <td>livro</td>
#       <td>21</td>
#       <td>[ações, problema, procedimentos, procrastinadores, sintomas, livro, técnicas]</td>
#       <td>7</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>O que mais me chamou a atenção no livro foi a explicação dos fenômenos da procrastinação baseados na ciência. Com explicações fáceis de entender, a autora parte da realidade em busca de soluções que atendam aos problemas em questão. Muito bom!</td>
#       <td>livro</td>
#       <td>41</td>
#       <td>[ciência, fenômenos, explicação, problemas, parte, explicações, realidade, livro, soluções, busca, procrastinação, questão, atenção]</td>
#       <td>13</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>É um bom livro. Baseado em vários estudos científicos. Contém informações que nos faz entender o comportamento do cérebro quando tarefas são procrastinadas.</td>
#       <td>livro</td>
#       <td>23</td>
#       <td>[estudos, tarefas, comportamento, cérebro, informações, livro]</td>
#       <td>6</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>O livro sintetiza boa parte das ideias que sugere, trazendo boas fontes e referências. Mas há deslizes de revisão muito graves. O discurso dos últimos parágrafos, num mote “deixe de ser perdedor”, contrasta com os valores anti-palestra motivacional. E, salvo engano, não há maiores informações sobre a autoria - o que nos leva a pensar em um pseudônimo. Isso também enfraquece o trabalho.</td>
#       <td>livro</td>
#       <td>63</td>
#       <td>[mote, parágrafos, valores, revisão, discurso, engano, pseudônimo, trabalho, parte, informações, deslizes, ideias, livro, anti-palestra, autoria, fontes, referências]</td>
#       <td>17</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>O livro eh uma confusão de informações, mal estruturado, desorganizado. Da algumas linhas gerais sobre o assunto, mas precisaria melhorar muito para ganhar mais algumas estrelas.</td>
#       <td>livro</td>
#       <td>26</td>
#       <td>[confusão, linhas, estrelas, informações, livro, assunto]</td>
#       <td>6</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# Cluster  4
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>review</th>
#       <th>produto</th>
#       <th>tamanho_review</th>
#       <th>substantivos</th>
#       <th>qtde_subs</th>
#       <th>cluster</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>11</th>
#       <td>Poderia dar uma nota maior, mas não funciona para tudo o que promete. O app Alexa não importa todos os contatos do telefone e assim não consigo usar para ligações. Se você não desembolsar para comprar caríssimos devices de lâmpada e tomada, o Echo acaba não servindo pra nada. Só serve para dizer tempo, hora e tocar música.</td>
#       <td>echodot</td>
#       <td>58</td>
#       <td>[nota, lâmpada, ligações, música, devices, hora, contatos, telefone, echo, tempo]</td>
#       <td>10</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>O echo dot é super prático, fácil de configurar, é perfeito para quem quer uma smart home.</td>
#       <td>echodot</td>
#       <td>17</td>
#       <td>[smart, echo, super]</td>
#       <td>3</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Além de todas as funcionalidades que eu já esperava, como controlar a luz, criar alarmes e lembretes, tocar música no Spotify, entre outras, tive a surpresa de descobrir que ela lê meus ebooks do Kindle em voz alta e com uma entonação incrível (sem parecer artificial). As skills são um show a parte - minhas preferidas são a do Cinemark, Turma da Mônica e sons relaxantes (ampla variedade). Não testei ainda as skills do Uber e iFood.</td>
#       <td>echodot</td>
#       <td>77</td>
#       <td>[surpresa, show, música, sons, ebooks, alarmes, luz, entonação, parecer, skills, lembretes, parte, variedade, funcionalidades, voz]</td>
#       <td>15</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Echo Dot limita diversos acessos do cliente. Por exemplo. Peço para tocar notícias da Jovem Pan e ela só atende notícias da CBN. Ou seja, a forma de atualização é obrigatoriamente por uma empresa do sistema Globo de Comunicação. Não toca Podcasts das diversas plataformas. Não reconhece a formatação de playlist fora da Amazon Music. Em suma. Caso você queira um tocador de música cheio de limitações acionado por voz, e que querhe obrigar a dar audiência informações da Globo, eis um bom produto. Caso você queira liberdade para ouvir e se informar onde deseja, não recomendo.</td>
#       <td>echodot</td>
#       <td>97</td>
#       <td>[notícias, globo, tocador, formatação, atualização, liberdade, suma, limitações, sistema, acessos, exemplo, forma, informações, empresa, audiência, plataformas, produto, música, cliente, limita, voz]</td>
#       <td>21</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Decepcionado, Alexa não entende meus comandos, não tem integração com YouTube music, apesar de seu ser prime eu não consigo usar o Amazon music, penso inclusive em devolver.Decepcionado, Alexa não entende meus comandos, não tem integração com YouTube music, apesar de seu ser prime eu não consigo usar o Amazon music, penso inclusive em devolver.</td>
#       <td>echodot</td>
#       <td>55</td>
#       <td>[integração, comandos]</td>
#       <td>2</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Muito bom. Só podia funcionar juntamente com o Fire Stick e melhorar a função de escolha de playlist no Spotify (não reconhece e não coloca as músicas no aleatório), mas no geral é ok.</td>
#       <td>echodot</td>
#       <td>34</td>
#       <td>[função, escolha, playlist, músicas, geral, aleatório]</td>
#       <td>6</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Cluster 0  -> avaliações apenas de petiscos de cachorro (100)
# ### Cluster 1 -> avaliações kindle (5/11) e echodot (3/10)
# ### Cluster 2 -> avaliações kindle (5/11), echodot(1/10), livro (1/9)
# ### Cluster 3 -> avaliações livro(8/9), avaliações kindle (1/11),
# ### Cluster 4 -> avaliações (6/10)

# %%
df[df["cluster"] == 4]
# Out:
#                                                review  produto  \
# 11  Poderia dar uma nota maior, mas não funciona p...  echodot
# 13  O echo dot é super prático, fácil de configura...  echodot
# 14  Além de todas as funcionalidades que eu já esp...  echodot
# 18  Echo Dot limita diversos acessos do cliente. P...  echodot
# 19  Decepcionado, Alexa não entende meus comandos,...  echodot
# 20  Muito bom. Só podia funcionar juntamente com o...  echodot
#
#     tamanho_review                                       substantivos  \
# 11              58  [nota, lâmpada, ligações, música, devices, hor...
# 13              17                               [smart, echo, super]
# 14              77  [surpresa, show, música, sons, ebooks, alarmes...
# 18              97  [notícias, globo, tocador, formatação, atualiz...
# 19              55                             [integração, comandos]
# 20              34  [função, escolha, playlist, músicas, geral, al...
#
#     qtde_subs  cluster  cluster_euclid  clusters_cos
# 11         10        4               4             3
# 13          3        4               4             0
# 14         15        4               4             4
# 18         21        4               4             4
# 19          2        4               4             4
# 20          6        4               4             3

# %% [markdown]
# # Vamos gerar nuvens de palavras para entendermos um pouco mais os grupos

# %%
todaspalavras_cluster = {}
substantivos_clusters = {}
for cluster in sorted(df["cluster"].unique()):
    todaspalavras_cluster[cluster] = []
    substantivos_clusters[cluster] = []
    for nomes in df[df["cluster"] == cluster]["substantivos"].values:
        substantivos_clusters[cluster].extend(nomes)
    todaspalavras_cluster[cluster] = ' '.join(df[df["cluster"] == cluster]["review"].values)

# %% [markdown]
# ## Quais são os substantivos de cada grupo?

# %%
for k in substantivos_clusters.keys():
    wordcloud = substantivos_clusters[k]
    wordcloud_str = ' '.join(wordcloud)
    wordcloud = WordCloud(width=800, height=400, background_color ='white',
                      min_font_size = 7).generate(wordcloud_str)
    plt.figure(figsize=(8, 3), facecolor=None)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad=0)
    plt.title("Cluster "+str(k))
    plt.show()

# %% [markdown]
# ## Conclusões
#
#
# - O grupo 0 é muito bem caracterizado por palavras relacionadas a cachorro.
# - Apesar do grupo 1 e 2 terem 5 reviews de kindle é possível observar que a abordagem entre elas é diferente devido a nuvem de palavras. No grupo 1 as avaliações focam nas diferenças entre as gerações, já o grupo 2 possui avaliações do produto como um meio de leitura.
# - O grupo 3 é predominantemente composto de livros, e consequentemente apareceu a palavra livro e os diversos assuntos que são tratados nos livros, por exemplo: procrastinação, fundamentos, etc.
# - No grupo 4 é possível perceber funcionaliades do echodot: música, ligações, contatos, etc
#
# <b> Por que a palavra medo apareceu no grupo 1?</b>
# Vamos analisar as frases?
#
# <i> Não posso comparar com as outras geração pois esse é meu primeiro Kindle, mas como uma pessoa que gosta muito de ler e lia muito pelo celular, o Kindle tem uma enorme diferença, meu maior <b>medo</b> era que os olhos doessem, o que não aconteceu. Ele é maravilhoso. Só não recebi os 90 dias de kindle unlimited! (kindle)</i>
#
#
# <i> 'Muito boa. Ela tem design e dimensões bem discretas, serve para colocar em qualquer cômodo da cada sem <b>medo</b> de estragar a decoração ou algo do tipo (muito pelo contrário, ela combina com tudo!). A qualidade de som, comparado ao porte dela, é muito boa. Só calibrei um pouco os graves, para não ficar tão agudo e lá estava o som com uma qualidade bem legal. Volume suficiente para curtir um som sem incomodar vizinhos e afins, desde que seja ambiente interno (é claramente o foco dessa caixa, dado o porte). Os microfones tem um ótimo alcance e a Alexa funciona muito bem. Recomendo!' (echodot) </i>
#
#
# É posível perceber que os usuários que avaliaram esses produtos possuem determinada preocupações: medo de prejudicar a vista e medo de atrapalhar a decoração.

# %%
#df[df["cluster"] == 3]["substantivos"].apply(lambda x : "informações" in x)

# %%
#df.loc[29, "review"]

# %% [markdown]
# ## Quais são as palavras das reviews em cada um dos grupos?

# %%
portugues_stops = stopwords.words('portuguese')

# %%
for k in todaspalavras_cluster.keys():
    wordcloud_str = todaspalavras_cluster[k]
    wordcloud = WordCloud(width=800, height=400, background_color ='white', stopwords=portugues_stops,
                      min_font_size = 7).generate(wordcloud_str)
    plt.figure(figsize=(8, 3), facecolor=None)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad=0)
    plt.title("Cluster "+str(k))
    plt.show()

# %% [markdown]
# ## Conclusões
#
#
# - Note que se olhamos para todas as palavras das reviews não conseguimos diferenciar muito bem os grupos 1 e 2.
# - Há uma grande variabilidade de palavras e não conseguimos discrimar muito bem os grupos.

# %% [markdown]
# # Hipótese levantada:
#
# Encontrar características do meu cliente através dos feedbacks
